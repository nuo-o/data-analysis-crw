# %%
import pandas as pd
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
# %matplotlib inline
# import psycopg2;

# %%
conn = psycopg2.connect(dbname='COMPG011', host='127.0.0.1', user='postgres', password='password')
cur = conn.cursor()

# %% [markdown]
# ## Removing Outliers

# %%
# Perform a query with logic to remove outliers
# People with more headshots than total kills,
# more than 9 kills per round,
# and more than 4,000,000 headshots are removed (3946 total)
# This is an average of 5 kills in a 2 minute game * 12 hours/day * 365 days/year * 6 years

clipping_condition = '''a.total_kills / 9 <= b.total_rounds
                        AND a.total_kills_headshot <= a.total_kills
                        AND a.total_kills_headshot < 4000000'''

cur.execute('''SELECT a.user_id, a.total_kills_headshot
                FROM csgo.profiles a, 
                    (SELECT user_id, sum(total_rounds) AS total_rounds 
                    FROM csgo.maps_stats
                    GROUP BY user_id) b
                WHERE a.user_id = b.user_id
                AND a.total_kills_headshot IS NOT NULL
                AND %s''' %clipping_condition)

rows = cur.fetchall()
col_names = [desc.name for desc in cur.description]

df = pd.DataFrame(rows, columns = col_names)
headshots = np.flip(np.sort(df['total_kills_headshot']), axis=0)

# %%
cur.execute('''SELECT a.user_id, a.total_kills_headshot
                FROM csgo.profiles a, 
                    (SELECT user_id, sum(total_rounds) AS total_rounds 
                    FROM csgo.maps_stats
                    GROUP BY user_id) b
                WHERE a.user_id = b.user_id
                AND a.total_kills_headshot IS NOT NULL
                AND NOT (%s)''' %clipping_condition)

rows = cur.fetchall()
col_names = [desc.name for desc in cur.description]

df = pd.DataFrame(rows, columns = col_names)
headshots_excluded = np.flip(np.sort(df['total_kills_headshot']), axis=0)

# %%
df = pd.read_csv('kill-headshot.csv')
df.columns = ['total_kills_headshot']
headshots = np.sort(df['total_kills_headshot'])

# %%
headshots_excluded =
# Out:
# array([1002532,  760038,  387402, ...,       1,       1,       1])

# %% [markdown]
# ## Calculate moments
# ### Jacknife
# `c` is the number of splits created in the dataset. 10 is recommended by the slides.

# %%
c = 10
arrays = np.array_split(np.random.permutation(headshots), c)
indices = np.arange(c)

means = []
variances = []
skews = []
kurtoses = []

for i in indices:
    l_prime = np.concatenate([arrays[j] for j in indices if j != i])
    
    means.append(np.mean(l_prime))
    variances.append(np.var(l_prime))
    skews.append(scipy.stats.skew(l_prime))
    kurtoses.append(scipy.stats.kurtosis(l_prime))

# %%
# Setup plot
fig = plt.figure(1, figsize=(10,8))

ax = fig.add_subplot(2, 2, 1, label='plot1')
plt.plot(np.sort(means), label='mean')
plt.legend()

ax = fig.add_subplot(2, 2, 2, label='plot2')
plt.plot(np.sort(variances), color='orange', label='variance')
plt.legend()

ax = fig.add_subplot(2, 2, 3, label='plot3')
plt.plot(np.sort(skews), color='green', label='skew')
plt.legend()

# %% [markdown]
# ### Bootstrap
# `b` is the number of random draws from the dataset.
# `m` is the size of the random draws.

# %%
b = 10000
m = len(headshots)

means = []
variances = []
skews = []
kurtoses = []

for i in range(b):
    l_prime = np.random.choice(headshots, size=m, replace=True)
    
    means.append(np.mean(l_prime))
    variances.append(np.var(l_prime))
    skews.append(scipy.stats.skew(l_prime))
    kurtoses.append(scipy.stats.kurtosis(l_prime))
    
means = np.sort(means)
variances = np.sort(variances)
skews = np.sort(skews)
kurtoses = np.sort(kurtoses)

# %%
# Setup plot
fig = plt.figure(1, figsize=(10,8))

ax = fig.add_subplot(2, 2, 1, label='plot1')
ax.set_xlabel('Mean')
ax.set_ylabel('Count')
plt.hist(means, bins=100, label='mean')

ax = fig.add_subplot(2, 2, 2, label='plot2')
ax.set_xlabel('Variance')
plt.hist(variances, bins=100, color='orange', label='variance')

ax = fig.add_subplot(2, 2, 3, label='plot3')
ax.set_xlabel('Skew')
ax.set_ylabel('Count')
plt.hist(skews, bins=100, color='green', label='skew')

ax = fig.add_subplot(2, 2, 4, label='plot4')
ax.set_xlabel('Kurtosis')
plt.hist(kurtoses, bins=100, color='red', label='kurtosis')

plt.show()

# %%
fig.savefig('jacknife_moments.svg', format='svg', bbox_inches='tight')
plt.close()

# %%
mean_conf_inv = (np.percentile(means, 2.5), np.percentile(means, 97.5))
variance_conf_inv = (np.percentile(variances, 2.5), np.percentile(variances, 97.5))
skew_conf_inv = (np.percentile(skews, 2.5), np.percentile(skews, 97.5))
kurtosis_conf_inv = (np.percentile(kurtoses, 2.5), np.percentile(kurtoses, 97.5))

print('Mean confidence interval: %f %f' %mean_conf_inv)
print('Variance confidence interval: %f %f' %variance_conf_inv)
print('Skew confidence interval: %f %f' %skew_conf_inv)
print('Kurtosis confidence interval: %f %f' %kurtosis_conf_inv)
# Out:
# Mean confidence interval: 13110.920644 13353.780283
# Variance confidence interval: 253727527.743416 319110297.260307
# Skew confidence interval: 4.012833 12.623529
# Kurtosis confidence interval: 32.846229 525.771494

# %% [markdown]
# ### Whole dataset

# %%
mean = np.mean(headshots)
median = np.median(headshots)
variance = np.var(headshots)
skew = scipy.stats.skew(headshots)
kurtosis = scipy.stats.kurtosis(headshots)

print('Mean: %s' %mean)
print('Median: %s' %median)
print('Variance: %s' %variance)
print('Skew: %s' %skew)
print('Kurtosis: %s' %kurtosis)
# Out:
# Mean: 13230.4418553
# Median: 8401.0
# Variance: 280851486.321
# Skew: 7.848041037628898
# Kurtosis: 255.8391353222861

# %% [markdown]
# ### Body and tail (separately)

# %%
# Body
clip_point = 1495 
body_data = headshots[clip_point:]

mean = np.mean(body_data)
median = np.median(body_data)
variance = np.var(body_data)
skew = scipy.stats.skew(body_data)
kurtosis = scipy.stats.kurtosis(body_data)

print('Body')
print('Mean: %s' %mean)
print('Median: %s' %median)
print('Variance: %s' %variance)
print('Skew: %s' %skew)
print('Kurtosis: %s' %kurtosis)

# Tail
tail_data = headshots[:clip_point]

mean = np.mean(tail_data)
median = np.median(tail_data)
variance = np.var(tail_data)
skew = scipy.stats.skew(tail_data)
kurtosis = scipy.stats.kurtosis(tail_data)

print()
print('Tail')
print('Mean: %s' %mean)
print('Median: %s' %median)
print('Variance: %s' %variance)
print('Skew: %s' %skew)
print('Kurtosis: %s' %kurtosis)
# Out:
# Body
# Mean: 11651.7333693
# Median: 8150.0
# Variance: 123708180.899
# Skew: 1.5343154893948503
# Kurtosis: 2.2938012313626137
#
# Tail
# Mean: 87648.3311037
# Median: 75968.0
# Variance: 2032838751.5
# Skew: 9.170000992698569
# Kurtosis: 149.72929111012814

# %% [markdown]
# ## Plot histogram of data against an exponential distribution

# %%
max(headshots), min(headshots)
# Out:
# (1002532, 1)

# %%
data = headshots
clip_point = 1495
# data = headshots[clip_point:]

ax = plt.figure(1)
hist, bin_edges = np.histogram(data, bins=100)
plt.hist(data, bins=bin_edges)
plt.xlabel('total kill-headshot')
plt.ylabel('number of observations')
plt.show()

# %%
data = np.sort(df['total_kills_headshot'])

clip_point = 1495
data = data[clip_point:]
rank = np.flip(np.arange(1, len(data) + 1), axis=0) / (len(data) + 1)

plt.loglog(data, rank)
params = scipy.stats.expon.fit(data)

plt.plot(data[-1], rank[-1], color ='red')

# %%
clip_point = 1495
data = headshots[clip_point:]

# Setup plot
fig = plt.figure(1, figsize=(13,4))

# Plot body
ax = fig.add_subplot(1, 2, 1, label='plot5')
ax.set_xlabel('Total Headshots (Body)')
ax.set_ylabel('Density (normalised)')

# Plot histogram
hist, bin_edges = np.histogram(data, bins=200)
plt.hist(data, bins=bin_edges, density=True)

# Plot exponential curve
params = scipy.stats.expon.fit(data)

x_axis = np.linspace(min(data), max(data), 10000)
y_axis = scipy.stats.expon.pdf(x_axis, *params)
plt.plot(x_axis, y_axis, color='red')

# Plot tail
ax = fig.add_subplot(1, 2, 2, label='plot6')
ax.set_xlabel('Total Headshots (Tail)')

data = headshots[:clip_point]

# Plot histogram
hist, bin_edges = np.histogram(data, bins=200)
plt.hist(data, bins=bin_edges, density=True)

# Plot power law
power_law_pdf = lambda b, alpha, x: b * np.power(x, -(alpha + 1))

slope = -3.154488
intercept = 30.835438

x_axis = np.linspace(min(data), max(data), 10000)
y_axis = power_law_pdf(intercept, slope, x_axis)

#plt.plot(x_axis, y_axis, color='red')

plt.show()

# %% [markdown]
# ## Plot rank-frequency (log-log) of data
# The plot is overlaid with a exponential distribution and the tail has been fit with a power law.

# %%
data_sorted = np.sort(headshots)
rank = np.flip(np.arange(1, len(data_sorted) + 1), axis=0) / (len(data_sorted) + 1)

# Setup plot
fig = plt.figure(1)
ax = fig.add_subplot(1, 1, 1, label='plot6')
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('Rank (log scale)')
ax.set_ylabel('Frequency (log scale)')

# Plot included points
plt.scatter(data_sorted, rank, s=5, color='dimgrey')

# %%
data_sorted = np.sort(headshots)
rank = np.flip(np.arange(1, len(data_sorted) + 1), axis=0) / (len(data_sorted) + 1)

# Setup plot
fig = plt.figure(1)
ax = fig.add_subplot(1, 1, 1, label='plot6')
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('Rank (log scale)')
ax.set_ylabel('Frequency (log scale)')

# Plot included points
plt.scatter(data_sorted, rank, s=5, color='dimgrey')

# Plot exponential
params = scipy.stats.expon.fit(data_sorted)
y_axis = scipy.stats.expon.sf(data_sorted, *params)

plt.plot(data_sorted[:-250], y_axis[:-250], color='darkorange')

# Plot tail
clip_start = 1495

lin_data = data_sorted[-clip_start:]
lin_rank = rank[-clip_start:]

# Plot exponential
params = scipy.stats.expon.fit(data_sorted)
y_axis = scipy.stats.expon.sf(data_sorted, *params)

plt.plot(data_sorted[clip_start:], y_axis[clip_start:], color='darkorange')


slope, intercept, r_value, p_value, stderr = scipy.stats.linregress(np.log(lin_data), np.log(lin_rank))
y_axis = np.log(lin_data) * slope + intercept

plt.plot(lin_data, np.exp(y_axis), color='red')

plt.legend(['fit body', 'fit tail', 'sample distribution'])
plt.show()

print('Slope %f, Intercept %f' %(slope, intercept))
# Out:
# Slope -3.154488, Intercept 30.835438

# %%
data_sorted = np.sort(headshots)[-250:]
rank = np.flip(np.arange(1, len(data_sorted) + 1), axis=0) / (len(data_sorted) + 1)
params = scipy.stats.powerlaw.fit(data_sorted)
y_axis = scipy.stats.powerlaw.sf(data_sorted, *params)
plt.plot(data_sorted, y_axis, color='darkorange')

# %%
np.sort(df['total_kills_headshot'])[1495]
# Out:
# 260

# %%
fig = plt.figure(1)
ax = fig.add_subplot(1, 1, 1, label='plot6')
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('Rank (log scale)')
ax.set_ylabel('Frequency (log scale)')

data_sorted = np.sort(df['total_kills_headshot'])
rank = np.flip(np.arange(1, len(data_sorted) + 1), axis=0) / (len(data_sorted) + 1)
plt.scatter(data_sorted, rank, s=5, color='dimgrey')

data_sorted = np.sort(df['total_kills_headshot'])
rank = np.flip(np.arange(1, len(data_sorted) + 1), axis=0) / (len(data_sorted) + 1)
params = scipy.stats.expon.fit(data_sorted)
y_axis = scipy.stats.expon.sf(data_sorted, *params)
plt.plot(data_sorted[:-250], y_axis[:-250], color='darkorange')

data_sorted = np.sort(df['total_kills_headshot'])[1495:]
rank = np.flip(np.arange(1, len(data_sorted) + 1), axis=0) / (len(data_sorted) + 1)
params = scipy.stats.powerlaw.fit(data_sorted)
y_axis = scipy.stats.powerlaw.sf(data_sorted, *params)
plt.plot(data_sorted, y_axis, color='red')

# %%
fig.savefig('rank_freq_headshots.svg', format='svg', bbox_inches='tight')
plt.close()

# %% [markdown]
# ## Plot rank-frequency with excluded points

# %%
fig = plt.figure(1)
ax = fig.add_subplot(1, 1, 1, label='plot7')
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('Rank (log scale)')
ax.set_ylabel('Frequency (log scale)')

headshot_included = headshots
headshot_excluded = headshots_excluded
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-104-9a48718a1751> in <module>()
#       7
#       8 headshot_included = headshots
# ----> 9 headshot_excluded = headshots_excluded
#
# NameError: name 'headshots_excluded' is not defined

# %%
# Setup data
headshots_paired = np.stack((headshots, np.full(len(headshots), 0))).T
headshots_excluded_paired = np.stack((headshots_excluded, np.full(len(headshots_excluded), 1))).T
headshots_merged = np.concatenate([headshots_paired, headshots_excluded_paired])

data_sorted = headshots_merged[headshots_merged[:,0].argsort()]
colors = ['blue' if x == 0 else 'red' for x in data_sorted[:,1]]
rank = np.flip(np.arange(1, data_sorted.shape[0] + 1), axis=0) / (data_sorted.shape[0] + 1)

# Setup plot
fig = plt.figure(1)
ax = fig.add_subplot(1, 1, 1, label='plot7')
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('Rank (log scale)')
ax.set_ylabel('Frequency (log scale)')

# Plot included points
plt.scatter(data_sorted[:,0], rank, color=colors, s=3)

blue_patch = mpatches.Patch(color='blue', label='Included')
red_patch = mpatches.Patch(color='red', label='Excluded')
plt.legend(handles=[blue_patch, red_patch])

plt.show()

# %%
fig.savefig('rank_freq_inc_ex.svg', format='svg', bbox_inches='tight')
plt.close()

# %% [markdown]
# ## Find the clipping point in between the body and the tail
# Utilising the KS test

# %%
data_sorted = np.sort(df['total_kills_headshot'])
clip_count = 1495
clipped_data = data_sorted[:-clip_count]
params = scipy.stats.expon.fit(clipped_data)
kst = scipy.stats.kstest(clipped_data, 'powe', params)
kst
# Out:
# KstestResult(statistic=0.016924575694222566, pvalue=5.8562037099763945e-18)

# %%
scipy.stats.powerlaw

# %%
data_sorted = np.sort(headshots)

ks_values = []
for clip_count in range(1, 10000):
    clipped_data = data_sorted[:-clip_count]
    
    params = scipy.stats.expon.fit(clipped_data)
    kst = scipy.stats.kstest(clipped_data, 'expon', params)
    
    ks_values.append((clip_count, kst))
        
    if clip_count % 100 == 0:
        print('Finished iteration %i, %s' %(clip_count, kst))
# Out:
# Finished iteration 100, KstestResult(statistic=0.012801234604499334, pvalue=4.0359249689635314e-09)
# Finished iteration 200, KstestResult(statistic=0.0096336065385342895, pvalue=2.4252200339804565e-05)
# Finished iteration 300, KstestResult(statistic=0.0070099019943682395, pvalue=0.0050378779399443477)
# Finished iteration 400, KstestResult(statistic=0.0070636258499622295, pvalue=0.0046408196923223071)
# Finished iteration 500, KstestResult(statistic=0.0084973490983818734, pvalue=0.00031253320976215701)
# Finished iteration 600, KstestResult(statistic=0.0098503864404648755, pvalue=1.5657292179511938e-05)
# Finished iteration 700, KstestResult(statistic=0.01118228175565128, pvalue=5.3870041653960631e-07)
# Finished iteration 800, KstestResult(statistic=0.025288100657000989, pvalue=5.7329684270961376e-34)
# Finished iteration 900, KstestResult(statistic=0.018373971268642153, pvalue=4.190756255926277e-18)
# Finished iteration 1000, KstestResult(statistic=0.014828076230141207, pvalue=6.4036946986673551e-12)
# Finished iteration 1100, KstestResult(statistic=0.015937779139494901, pvalue=1.1057354377130495e-13)
# Finished iteration 1200, KstestResult(statistic=0.017001041623163904, pvalue=1.741262583437768e-15)
# Finished iteration 1300, KstestResult(statistic=0.026273759292988252, pvalue=2.4684459381138878e-36)
# Finished iteration 1400, KstestResult(statistic=0.019033291278118925, pvalue=3.0769030291865888e-19)
# Finished iteration 1500, KstestResult(statistic=0.020005541890549594, pvalue=3.562874696552142e-21)
# Finished iteration 1600, KstestResult(statistic=0.020954792965243774, pvalue=3.7510045811209277e-23)
# Finished iteration 1700, KstestResult(statistic=0.021905895530298924, pvalue=3.2058219767223051e-25)
# Finished iteration 1800, KstestResult(statistic=0.022709003742482081, pvalue=5.0043021269284647e-27)
# Finished iteration 1900, KstestResult(statistic=0.023659894053191743, pvalue=2.9754231962655521e-29)
# Finished iteration 2000, KstestResult(statistic=0.02453604795256098, pvalue=2.2453105245595767e-31)
# Finished iteration 2100, KstestResult(statistic=0.025394969320491845, pvalue=1.5939655727954191e-33)
# Finished iteration 2200, KstestResult(statistic=0.026234554164851986, pvalue=1.0902720762761052e-35)
# Finished iteration 2300, KstestResult(statistic=0.027124341114035722, pvalue=4.6648620608923434e-38)
# Finished iteration 2400, KstestResult(statistic=0.028004860517311381, pvalue=1.794921399427835e-40)
# Finished iteration 2500, KstestResult(statistic=0.029007957454750988, pvalue=2.5520830876642206e-43)
# Finished iteration 2600, KstestResult(statistic=0.029716010003622506, pvalue=2.3122817152803046e-45)
# Finished iteration 3600, KstestResult(statistic=0.037503699056352147, pvalue=8.8329055831350098e-71)
# Finished iteration 3700, KstestResult(statistic=0.038174180412689385, pvalue=3.424678612570315e-73)
# Finished iteration 3800, KstestResult(statistic=0.038940082744320759, pvalue=5.2138424718461114e-76)
# Finished iteration 3900, KstestResult(statistic=0.039646038467164968, pvalue=1.2254021492776924e-78)
# Finished iteration 4000, KstestResult(statistic=0.040341506114738968, pvalue=2.894441514450136e-81)
# Finished iteration 4100, KstestResult(statistic=0.041037872637487594, pvalue=6.2071089006994087e-84)
# Finished iteration 4200, KstestResult(statistic=0.041728508005951293, pvalue=1.2874457970167361e-86)
# Finished iteration 4300, KstestResult(statistic=0.042062891580555206, pvalue=7.5251815200857936e-88)
# Finished iteration 4400, KstestResult(statistic=0.04306197824409802, pvalue=6.8424149060706504e-92)
# Finished iteration 4500, KstestResult(statistic=0.043764811767426748, pvalue=9.8062259406835364e-95)
# Finished iteration 4600, KstestResult(statistic=0.044397833206353987, pvalue=2.5987684199473388e-97)
# Finished iteration 4700, KstestResult(statistic=0.044948282055457423, pvalue=1.4891849995303547e-99)
# Finished iteration 4800, KstestResult(statistic=0.045691551104329986, pvalue=1.1189147927233403e-102)
# Finished iteration 4900, KstestResult(statistic=0.046334784870350421, pvalue=2.1679545092436012e-105)
# Finished iteration 5000, KstestResult(statistic=0.046971625535576822, pvalue=4.1928973112437119e-108)
# Finished iteration 5100, KstestResult(statistic=0.047600244219990651, pvalue=8.2779112578222925e-111)
# Finished iteration 5200, KstestResult(statistic=0.048221212848417405, pvalue=1.6638068461502468e-113)
# Finished iteration 5300, KstestResult(statistic=0.048837981737356428, pvalue=3.2892635113098082e-116)
# Finished iteration 5400, KstestResult(statistic=0.049449740842867684, pvalue=6.4660231766820016e-119)
# Finished iteration 5500, KstestResult(statistic=0.050056434724220833, pvalue=1.2674935014062659e-121)
# Finished iteration 5600, KstestResult(statistic=0.049862231335480511, pvalue=1.809236804248257e-120)
# Finished iteration 5700, KstestResult(statistic=0.051254297486245104, pvalue=4.8898804890372785e-127)
# Finished iteration 5800, KstestResult(statistic=0.051844923435009072, pvalue=9.72628922701813e-130)
# Finished iteration 5900, KstestResult(statistic=0.052441610324073351, pvalue=1.7105836491476734e-132)
# Finished iteration 6000, KstestResult(statistic=0.063079966303406398, pvalue=3.6390719202753115e-191)
# Finished iteration 6100, KstestResult(statistic=0.053178390245594231, pvalue=9.7130600425313404e-136)
# Finished iteration 6200, KstestResult(statistic=0.054172518694280247, pvalue=1.3671060008920196e-140)
# Finished iteration 6300, KstestResult(statistic=0.054721339314350137, pvalue=3.4792587708793326e-143)
# Finished iteration 6400, KstestResult(statistic=0.055281189785116702, pvalue=7.4277659035150173e-146)
# Finished iteration 6500, KstestResult(statistic=0.055924927119621548, pvalue=5.4424253242925644e-149)
# Finished iteration 6600, KstestResult(statistic=0.056399613871887633, pvalue=3.0154902918115949e-151)
# Finished iteration 6700, KstestResult(statistic=0.056948949697304796, pvalue=6.4375940996955314e-154)
# Finished iteration 6800, KstestResult(statistic=0.057501806322347748, pvalue=1.2626031893314577e-156)
# Finished iteration 6900, KstestResult(statistic=0.058037554798464064, pvalue=2.9486990069425432e-159)
# Finished iteration 7000, KstestResult(statistic=0.058572205525645182, pvalue=6.7263706902707116e-162)
# Finished iteration 7100, KstestResult(statistic=0.059103888811404937, pvalue=1.5359703406422635e-164)
# Finished iteration 7200, KstestResult(statistic=0.059632920551973112, pvalue=3.5008321291884402e-167)
# Finished iteration 7300, KstestResult(statistic=0.060154064226531523, pvalue=8.532852486978751e-170)
# Finished iteration 7400, KstestResult(statistic=0.060675513345185006, pvalue=2.0033313016021113e-172)
# Finished iteration 7500, KstestResult(statistic=0.061188825804054714, pvalue=5.0633082805161384e-175)
# Finished iteration 7600, KstestResult(statistic=0.061954021086547573, pvalue=4.4024443353781905e-179)
# Finished iteration 7700, KstestResult(statistic=0.062204644215908322, pvalue=3.3995035586820763e-180)
# Finished iteration 7800, KstestResult(statistic=0.062707752334377143, pvalue=8.9799133149049662e-183)
# Finished iteration 7900, KstestResult(statistic=0.063206791234283188, pvalue=2.434584511972143e-185)
# Finished iteration 8000, KstestResult(statistic=0.063703109187845108, pvalue=6.6603733477594772e-188)
# Finished iteration 8100, KstestResult(statistic=0.066499809677107558, pvalue=2.4263250189030083e-204)
# Finished iteration 8200, KstestResult(statistic=0.06493555836523518, pvalue=1.7047522656746922e-194)
# Finished iteration 8300, KstestResult(statistic=0.065162108862614976, pvalue=1.7536881423558919e-195)
# Finished iteration 8400, KstestResult(statistic=0.065643497085450531, pvalue=5.3161933305033118e-198)
# Finished iteration 8500, KstestResult(statistic=0.066118673513436366, pvalue=1.7162142141056161e-200)
# Finished iteration 8600, KstestResult(statistic=0.066591278692750944, pvalue=5.6160869944812589e-203)
# Finished iteration 8700, KstestResult(statistic=0.067065722698525287, pvalue=1.7521906398226081e-205)
# Finished iteration 8800, KstestResult(statistic=0.067533802578220503, pvalue=5.852959603592913e-208)
# Finished iteration 8900, KstestResult(statistic=0.068002647718877207, pvalue=1.8944626355366245e-210)
# Finished iteration 9000, KstestResult(statistic=0.068460770065089771, pvalue=7.0026894324960914e-213)
# Finished iteration 9100, KstestResult(statistic=0.068918843651742612, pvalue=2.5422437823540096e-215)
# Finished iteration 9200, KstestResult(statistic=0.069756065979347692, pvalue=3.7589527469553171e-220)
# Finished iteration 9300, KstestResult(statistic=0.067533659348734898, pvalue=5.6102729166723657e-206)
# Finished iteration 9400, KstestResult(statistic=0.070270442187786664, pvalue=1.5150941415328468e-222)
# Finished iteration 9500, KstestResult(statistic=0.070713785605005963, pvalue=6.3557631178992539e-225)
# Finished iteration 9600, KstestResult(statistic=0.071152801211386063, pvalue=2.7972841209500724e-227)
# Finished iteration 9700, KstestResult(statistic=0.071587634214492324, pvalue=1.2902333081551877e-229)
# Finished iteration 9800, KstestResult(statistic=0.072017059046937948, pvalue=6.3573099157775132e-232)
# Finished iteration 9900, KstestResult(statistic=0.072443949862977197, pvalue=3.2100917541617271e-234)

# %% [markdown]
# ## Plot the statistics calculated above

# %%
plt.plot(range(1, len(ks_values) + 1), list(map(lambda x: x.pvalue, list(zip(*ks_values))[1])))
plt.show()

# %%
plt.plot(range(1, len(ks_values) + 1), list(map(lambda x: x.statistic, list(zip(*ks_values))[1])))
plt.show()

# %%
data_sorted = np.sort(headshots)

anderson_values = []
for clip_count in range(1, 10000):
    clipped_data = data_sorted[:-clip_count]

    anderson = scipy.stats.anderson(clipped_data, 'expon')
    
    anderson_values.append((clip_count, anderson))
        
    if clip_count % 100 == 0:
        print('Finished iteration %i, %s' %(clip_count, anderson))
# Out:
# Finished iteration 100, AndersonResult(statistic=102.36599281225062, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 200, AndersonResult(statistic=74.041840948630124, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 300, AndersonResult(statistic=54.141496881522471, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 400, AndersonResult(statistic=39.30521632982709, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 500, AndersonResult(statistic=28.093695642281091, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 600, AndersonResult(statistic=19.677959192980779, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 700, AndersonResult(statistic=13.467302045377437, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 800, AndersonResult(statistic=9.1020675515610492, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 900, AndersonResult(statistic=6.2616387889138423, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 1000, AndersonResult(statistic=4.6927546687365975, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 1100, AndersonResult(statistic=4.2056522135826526, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 1200, AndersonResult(statistic=4.6423851507424843, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 1300, AndersonResult(statistic=5.9020706666487968, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 1400, AndersonResult(statistic=7.8798856891517062, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 1500, AndersonResult(statistic=10.514592526291381, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 1600, AndersonResult(statistic=13.739818280664622, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 1700, AndersonResult(statistic=17.432352093834197, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 1800, AndersonResult(statistic=21.532669918538886, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 1900, AndersonResult(statistic=26.018384040624369, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 2000, AndersonResult(statistic=30.833993745356565, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 2100, AndersonResult(statistic=35.948127419018419, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 2200, AndersonResult(statistic=41.320616381795844, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 2300, AndersonResult(statistic=46.942106262926245, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 2400, AndersonResult(statistic=52.777747670697863, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 2500, AndersonResult(statistic=58.829408152436372, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 2600, AndersonResult(statistic=65.057948468529503, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 2700, AndersonResult(statistic=71.455171064924798, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 2800, AndersonResult(statistic=78.01889920202666, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 2900, AndersonResult(statistic=84.704888284133631, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 3000, AndersonResult(statistic=91.494684362623957, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 3100, AndersonResult(statistic=98.410995613739942, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 3200, AndersonResult(statistic=105.39129584281181, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 3300, AndersonResult(statistic=112.44743351321085, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 3400, AndersonResult(statistic=119.60330508941843, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 3500, AndersonResult(statistic=126.8467462870467, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 3600, AndersonResult(statistic=134.17847268024343, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 3700, AndersonResult(statistic=141.54648765106685, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 3800, AndersonResult(statistic=148.92757051021908, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 3900, AndersonResult(statistic=156.3814453791565, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 4000, AndersonResult(statistic=163.89512789365835, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 4100, AndersonResult(statistic=171.4422960242664, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 4200, AndersonResult(statistic=179.03630782118125, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 4300, AndersonResult(statistic=186.70342129351047, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 4400, AndersonResult(statistic=194.3320505949232, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 4500, AndersonResult(statistic=201.97308591697947, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 4600, AndersonResult(statistic=209.62721426592907, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 4700, AndersonResult(statistic=217.33000850985991, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 4800, AndersonResult(statistic=225.05655330576701, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 4900, AndersonResult(statistic=232.84336517822521, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 5000, AndersonResult(statistic=240.62128246251086, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 5100, AndersonResult(statistic=248.36911582591711, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 5200, AndersonResult(statistic=256.137772368078, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 5300, AndersonResult(statistic=263.88741953400313, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 5400, AndersonResult(statistic=271.59971748152748, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 5500, AndersonResult(statistic=279.35519520343223, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 5600, AndersonResult(statistic=287.13940795093367, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 5700, AndersonResult(statistic=294.95329140205286, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 5800, AndersonResult(statistic=302.80593771017448, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 5900, AndersonResult(statistic=310.66115380206611, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 6000, AndersonResult(statistic=318.50662773396471, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 6100, AndersonResult(statistic=326.33904541711672, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 6200, AndersonResult(statistic=334.17972738368553, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 6300, AndersonResult(statistic=342.03966708331427, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 6400, AndersonResult(statistic=349.89698367698293, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 6500, AndersonResult(statistic=357.77654963871464, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 6600, AndersonResult(statistic=365.62583205384726, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 6700, AndersonResult(statistic=373.42127235989028, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 6800, AndersonResult(statistic=381.13106914173113, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 6900, AndersonResult(statistic=388.83782387398242, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 7000, AndersonResult(statistic=396.5741416747187, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 7100, AndersonResult(statistic=404.31626992009842, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 7200, AndersonResult(statistic=412.03743822874821, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 7300, AndersonResult(statistic=419.76960627853987, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 7400, AndersonResult(statistic=427.49102842699358, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 7500, AndersonResult(statistic=435.20138174119347, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 7600, AndersonResult(statistic=442.90162756758946, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 7700, AndersonResult(statistic=450.57441495776584, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 7800, AndersonResult(statistic=458.22536297211627, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 7900, AndersonResult(statistic=465.84548334654392, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 8000, AndersonResult(statistic=473.42267927449575, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 8100, AndersonResult(statistic=481.00297472221428, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 8200, AndersonResult(statistic=488.60068143340322, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 8300, AndersonResult(statistic=496.20926729805069, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 8400, AndersonResult(statistic=503.80714038164297, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 8500, AndersonResult(statistic=511.34505776532023, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 8600, AndersonResult(statistic=518.83362592579215, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 8700, AndersonResult(statistic=526.31810146493081, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 8800, AndersonResult(statistic=533.79015907534631, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 8900, AndersonResult(statistic=541.21253829017951, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 9000, AndersonResult(statistic=548.61494139404385, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 9100, AndersonResult(statistic=555.97746105297119, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 9200, AndersonResult(statistic=563.34573390013247, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 9300, AndersonResult(statistic=570.66510672943696, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 9400, AndersonResult(statistic=577.94135222400655, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 9500, AndersonResult(statistic=585.18163031860604, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 9600, AndersonResult(statistic=592.35416943616292, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 9700, AndersonResult(statistic=599.47933938864298, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 9800, AndersonResult(statistic=606.57714016093087, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# Finished iteration 9900, AndersonResult(statistic=613.66632993405801, critical_values=array([ 0.922,  1.078,  1.341,  1.606,  1.957]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))

# %%
plt.plot(range(1, len(anderson_values) + 1), list(map(lambda x: x.statistic, list(zip(*anderson_values))[1])))
plt.show()

# %%
np.sort(df['total_kills_headshot'])[338]
# Out:
# 61

# %%
ks_min = sorted(ks_values, key=lambda x: x[1].statistic)[0]
anderson_min = sorted(anderson_values, key=lambda x: x[1].statistic)[0]

print('KS minimum: %i, %f' %(ks_min[0], ks_min[1].statistic))
print('Anderson minimum: %i, %f' %(anderson_min[0], anderson_min[1].statistic))
# Out:
# KS minimum: 338, 0.006102
# Anderson minimum: 1, 59.562653

# %% [markdown]
# ## Show differences in mean and median headshots based on player rank

# %%
cur.execute('''SELECT a.id, b.total_kills_headshot FROM csgo.ranks a, csgo.profiles b 
                WHERE a.id = b.rank_id AND 
                        b.total_kills_headshot IS NOT NULL AND
                        b.total_kills_headshot <= b.total_kills
                ORDER BY b.total_kills_headshot DESC''')

rows = cur.fetchall()
col_names = [desc.name for desc in cur.description]

# %%
df = pd.DataFrame(rows, columns = col_names)

# %%
for i in range(1, 19):
    print("Rank %i: median %f, mean %f" %(i, np.median(df[df.id == i].total_kills_headshot), np.mean(df[df.id == i].total_kills_headshot)))
# Out:
# Rank 1: median 952.000000, mean 2371.569729
# Rank 2: median 2240.000000, mean 3067.677348
# Rank 3: median 2620.000000, mean 3746.041815
# Rank 4: median 2982.000000, mean 18692.984609
# Rank 5: median 3437.000000, mean 4449.990172
# Rank 6: median 3899.000000, mean 35314.383014
# Rank 7: median 4656.500000, mean 5859.850202
# Rank 8: median 5487.000000, mean 6933.175837
# Rank 9: median 6224.000000, mean 7616.107580
# Rank 10: median 7285.000000, mean 9281.824201
# Rank 11: median 8781.000000, mean 22555.872724
# Rank 12: median 10076.000000, mean 198340.401729
# Rank 13: median 11630.000000, mean 208269.876726
# Rank 14: median 13300.500000, mean 382442.064652
# Rank 15: median 15661.000000, mean 40436.170927
# Rank 16: median 18419.000000, mean 307587.264569
# Rank 17: median 22041.000000, mean 26348.679380
# Rank 18: median 30037.000000, mean 37910.376481
